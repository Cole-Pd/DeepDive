# %% [markdown]
# <a href="https://colab.research.google.com/github/Cole-Pd/DeepDive/blob/main/Dog_cat_random_image_generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Modules

# %%
import pickle #reads the file
import numpy as np # makes matrixes and vectors speedy
import matplotlib.pyplot as plt #this displays the image

# %% [markdown]
# ## Import Data

# %% [markdown]
# * Load pickled data from cats_dogs.pickle

# %%
cats_dogs_pickle = '/content/X.pickle' #this line assigns the path to the pickle file to a variable.
dataset = pickle.load(open(cats_dogs_pickle,'rb'))
len(dataset) #this is how many images are in the dataset. it should be equal to 24946
# Out:
# 24946

# %% [markdown]
# ## Fit the images and select a random image

# %% [markdown]
# * Scale the encoded images so that they fall between 0 and 1 by dividing by 255.

# %%
dataset = (dataset)/255

# %% [markdown]
# ## Display a randomly selected Image

# %%
#you can click play many times to generate a new random image
random_index = np.random.randint(len(dataset)) #Generates a random number from the datset
plt.imshow(dataset[random_index], 'Greys_r') ; #Display's the image
plt.title(random_index); #Gives the image a title

# The number in the title coorespods to the index in the dataset of this image.
# In the cell below you can choose this image without the index at the top.

# %% [markdown]
# ## Display a non-random image

# %%
# To change the image you generate change the number inside the brackets of 'dataset[38]'.
# The emotionally aware pup is index number 38.

# They should all be dogs and cats buuut some might not be ex 11218 and 13596. i think it is like a family photo.

 # Example 'dataset[enter a number here]' -> 'dataset[21453]' -> shows image 21453
    # Try 'dataset[18258]' its a gem. and 'dataset[23122] has a cone :D
plt.imshow(dataset[38], 'Greys_r') ; # you can also change the colormap.

# %%
plt.imshow(dataset[38], 'Purples_r' ); #add any of the below to change the color map
                  #Ex: ^'gist_rainbow_r'^

#'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r',
# 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r',
# 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges',
# 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r',
# 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r',
# 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu',
# 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn',
# 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3',
# 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu',
# 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r',
# 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r',
# 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r',
# 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r',
# 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'gist_earth', 'gist_earth_r',
# 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar',
# 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern',
# 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2',
# 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv',
# 'hsv_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r',
# 'nipy_spectral', 'nipy_spectral_r', 'ocean',

# %% [markdown]
# ## Display a randomly selected image with a title and no axis.

# %%
random_index = np.random.randint(len(dataset))
plt.imshow(dataset[random_index],'Greys_r') ;
plt.axis('off');
# Place a '#' sign in front of "plt.title('')" to turn the title off
plt.title('This is a pup?') ; #Change your title by changing the text between the quotes.

# %% [markdown]
# ## Display a non-random

# %%
plt.imshow(dataset[38],'Greys') ;
plt.axis('off')

#plt.title('add a title between the quotes and delete the #')
#  Change text position
#        V    V
plt.text(50, 10,'BE AN OBSERVER OF THE EMOTIONS', ha='center', va='center', fontsize=14, color='Blue');

plt.text(50, 90,'FEEL AND RELEASE THEM', ha='center', va='center', fontsize=14, color='Black');
#                  ^ Change TEXT ^
